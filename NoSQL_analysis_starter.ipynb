# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
food_list= db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
pprint(food_list.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d9a338ccf4bbea612ff777'),
#  'geocode': {' $toDecimal': 'geocode.latitude',
#              'latitude': {' $toDecimal': 'geocode.latitude',
#                           ' $toFloat': 'geocode.latitude'},
#              'longitude': {' $toDecimal': 'geocode.longitude',
#                            ' $toFloat': 'geocode.longitude',
#                            '$toDecimal': 'geocode.longitude'}},
#  'latitude': {' $toDecimal': 'latitude'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene' :{'$eq': 20} }




# Use count_documents to display the number of documents in the result
results_count=food_list.count_documents(query)
print(results_count)
# Display the first document in the results using pprint
results=list(food_list.find(query))

print(results)
#for result in results:
 #   pprint(results)
# Out:
# 41
# [{'_id': ObjectId('63d9a338ccf4bbea613012ac'), 'FHRSID': 110681, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '4029', 'BusinessName': 'The Chase Rest Home', 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5, 'AddressLine1': '5-6 Southfields Road', 'AddressLine2': 'Eastbourne', 'AddressLine3': 'East Sussex', 'AddressLine4': '', 'PostCode': 'BN21 1BU', 'Phone': '', 'RatingValue': '0', 'RatingKey': 'fhrs_0_en-gb', 'RatingDate': '2021-09-23T00:00:00', 'LocalAuthorityCode': '102', 'LocalAuthorityName': 'Eastbourne', 'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings', 'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk', 'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20}, 'SchemeType': 'FHRS', 'geocode': {'longitude': {'$toDecimal': 'geocode.longitude', ' $toFloat': 'geocode.longitude', ' $toDecimal': 'geocode.longitude'}, 'latitude': {' $toDecimal': 'geocode.latitude', ' $toFloat': 'geocode.latitude'}, ' $toDecimal': 'geocode.latitude'}, 'RightToReply': '', 'Distance': 4613.888288172291, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/110681'}], 'latitude': {' $toDecimal': 'latitude'}}, {'_id': ObjectId('63d9a338ccf4bbea6130162d'), 'FHRSID': 612039, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '1970/FOOD', 'BusinessName': 'Brenalwood', 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5, 'AddressLine1': 'Hall Lane', 'AddressLine2': 'Walton-on-the-Naze', 'AddressLine3': 'Essex', 'AddressLine4': '', 'PostCode': 'CO14 8HN', 'Phone': '', 'RatingValue': '0', 'RatingKey': 'fhrs_0_en-gb', 'RatingDate': '2022-06-22T00:00:00', 'LocalAuthorityCode': '120', 'LocalAuthorityName': 'Tendring', 'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/', 'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk', 'scores': {'Hygiene': 20, 'Structural': 15, 'ConfidenceInManagement': 30}, 'SchemeType': 'FHRS', 'geocode': {'longitude': {'$toDecimal': 'geocode.longitude', ' $toFloat': 'geocode.longitude', ' $toDecimal': 'geocode.longitude'}, 'latitude': {' $toDecimal': 'geocode.latitude', ' $toFloat': 'geocode.latitude'}, ' $toDecimal': 'geocode.latitude'}, 'RightToReply': '', 'Distance': 4617.965823673803, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/612039'}], 'latitude': {' $toDecimal': 'latitude'}}, {'_id': ObjectId('63d9a338ccf4bbea61301935'), 'FHRSID': 730933, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '1698/FOOD', 'BusinessName': 'Melrose Hotel', 'BusinessType': 'Hotel/bed & breakfast/guest house', 'BusinessTypeID': 7842, 'AddressLine1': '53 Marine Parade East', 'AddressLine2': 'Clacton On Sea', 'AddressLine3': 'Essex', 'AddressLine4': '', 'PostCode': 'CO15 6AD', 'Phone': '', 'RatingValue': '0', 'RatingKey': 'fhrs_0_en-gb', 'RatingDate': '2021-08-13T00:00:00', 'LocalAuthorityCode': '120', 'LocalAuthorityName': 'Tendring', 'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/', 'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk', 'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20}, 'SchemeType': 'FHRS', 'geocode': {'longitude': {'$toDecimal': 'geocode.longitude', ' $toFloat': 'geocode.longitude', ' $toDecimal': 'geocode.longitude'}, 'latitude': {' $toDecimal': 'geocode.latitude', ' $toFloat': 'geocode.latitude'}, ' $toDecimal': 'geocode.latitude'}, 'RightToReply': '', 'Distance': 4619.6561440278165, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'page ...

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the numbreer of rows in the DataFrame

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  63d9a338ccf4bbea613012ac   110681                  0
# 1  63d9a338ccf4bbea6130162d   612039                  0
# 2  63d9a338ccf4bbea61301935   730933                  0
# 3  63d9a338ccf4bbea61301b25   172735                  0
# 4  63d9a338ccf4bbea61301b33   172953                  0
# 5  63d9a338ccf4bbea613024d5   512854                  0
# 6  63d9a338ccf4bbea613026f4  1537089                  0
# 7  63d9a338ccf4bbea61303c1d   155648                  0
# 8  63d9a338ccf4bbea61304062  1012883                  0
# 9  63d9a338ccf4bbea61304874   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': {'$toDecimal': 'geocode.longitud...
# 1  {'longitude': {'$toDecimal': 'geocode.longitud...
# 2  {'longitude': {'$toDecimal': 'geocode.longitud...
# 3  {'longitude': {'$toDecimal': 'geocode.longitud...
# 4  {'longitude': {'$toDecimal': 'geocode.longitud...
# 5  {'longitude': {'$toDecimal': 'geocode.longitud...
# 6  {'longitude': {'$toDecimal': 'geocode.longitud...
# 7  {'longitude': {'$toDecimal': 'geocode.longitud...
# 8  {'longitude': {'$toDecimal': 'geocode.longitud...
# 9  {'longitude': {'$toDecimal': 'geocode.longitud...
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                       latitude
# 0  {' $toDecimal': 'latitude'}
# 1  {' $toDecimal': 'latitude'}
# 2  {' $toDecimal': 'latitude'}
# 3  {' $toDecimal': 'latitude'}
# 4  {' $toDecimal': 'latitude'}
# 5  {' $toDecimal': 'latitude'}
# 6  {' $toDecimal': 'latitude'}
# 7  {' $toDecimal': 'latitude'}
# 8  {' $toDecimal': 'latitude'}
# 9  {' $toDecimal': 'latitude'}
#
# [10 rows x 29 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={'LocalAuthorityName':'London'}

# Use count_documents to display the number of documents in the result
results_count1=food_list.count_documents(query)
print(results_count1)
# Display the first document in the results using pprint
results2=list(food_list.find(query))
print(results2)
# Out:
# 0
# []

# %%
# Convert the result to a Pandas DataFrame
result_df2 = pd.DataFrame(results2)
# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
result_df2.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 
longitude = 

query = 
sort =  

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
